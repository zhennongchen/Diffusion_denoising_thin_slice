# %% [markdown]
# Training, Validation and testing dataset were labeled by batch manually

# %%
import sys
sys.path.append('/host/d/Github/')
import os
import numpy as np
import pandas as pd
import nibabel as nb
import Diffusion_denoising_thin_slice.functions_collection as ff

# %%
patient_sheet = ff.find_all_target_files(['*'],os.path.join('/host/d/Data/NYU_MR/multicoil_train/ref'))
print('total patient num: ', len(patient_sheet))
# Out:
# total patient num:  50

# %%
# shuffle these patients
np.random.seed(42)
shuffled_indices = np.random.permutation(len(patient_sheet))
patient_sheet = [patient_sheet[i] for i in shuffled_indices]

# %%
# 
results = []
for i in range(0, len(patient_sheet)):
    patient_id = os.path.basename(patient_sheet[i])
    # first 35 are train, next 5 are val, last 10 are test   
    if i < 35:
        batch = 'train'
    elif i<40 and i>=35:
        batch = 'val'
    else:
        batch = 'test'
    results.append([batch, patient_id])
df = pd.DataFrame(results, columns=['batch','Patient_ID'])
ff.make_folder(['/host/d/Data/NYU_MR/Patient_lists'])
save_path = os.path.join('/host/d/Data/NYU_MR/Patient_lists','NYU_MR_batched.xlsx')
df.to_excel(save_path, index=False)

# %% [markdown]
# # build list for simulations

# %%
patient_sheet = pd.read_excel(os.path.join('/host/d/Data/NYU_MR/Patient_lists/NYU_MR_batched.xlsx'),dtype={'Patient_ID': str})
simulation_num = 1

data_path = '/host/d/Data/NYU_MR/multicoil_train'


results = []
for i in range(0, len(patient_sheet)):
    patient_id = patient_sheet['Patient_ID'][i]
    batch = patient_sheet['batch'][i]
    print(f"Processing patient {patient_id} in batch {batch}")


    ground_truth_file = os.path.join(data_path,'ref', patient_id, 'img.nii.gz')
    img = nb.load(ground_truth_file).get_fdata()
    print('ground truth shape:', img.shape)
    slice_num = img.shape[0]
 
    max_value = np.max(img)
    min_value = np.min(img)
    print('ground truth max and min value:', max_value, min_value)

    x_dim, y_dim = img.shape[1], img.shape[2]


    for n in range(0,simulation_num):
        simulation_file_all =''
        simulation_file_odd = os.path.join(data_path,'undersample_8', patient_id, 'random_' + str(n), 'recon1', 'img.nii.gz')
        simulation_file_even = os.path.join(data_path,'undersample_8', patient_id, 'random_' + str(n), 'recon2', 'img.nii.gz')
            

        results.append([batch,patient_id, n, simulation_file_all, simulation_file_odd, simulation_file_even, ground_truth_file, slice_num, x_dim, y_dim, max_value, min_value])

        df = pd.DataFrame(results, columns=['batch','Patient_ID', 'random_num', 'simulation_file_all','simulation_file_odd', 'simulation_file_even', 'ground_truth_file', 'slice_num', 'x_dim', 'y_dim', 'max_value', 'min_value'])
        df.to_excel(os.path.join('/host/d/Data/NYU_MR/Patient_lists','NYU_MR_simulation.xlsx'), index=False)
# Out:
# Processing patient file1000176 in batch train
# ground truth shape: (36, 640, 320)
# ground truth max and min value: 0.00024828744763237006 5.321381196150904e-09
# Processing patient file1000486 in batch train
# ground truth shape: (35, 640, 320)
# ground truth max and min value: 0.00015094980406731517 5.34433555772473e-09
# Processing patient file1000401 in batch train
# ground truth shape: (36, 640, 320)
# ground truth max and min value: 0.0003873487792687884 1.3839940417560417e-09
# Processing patient file1000540 in batch train
# ground truth shape: (33, 640, 320)
# ground truth max and min value: 0.0001635280769631598 1.5471714286768164e-09
# Processing patient file1000233 in batch train
# ground truth shape: (35, 640, 320)
# ground truth max and min value: 0.00016510124911750407 7.305896232114525e-10
# Processing patient file1000584 in batch train
# ground truth shape: (38, 640, 320)
# ground truth max and min value: 0.0011870991823825108 2.154442452000412e-09
# Processing patient file1000363 in batch train
# ground truth shape: (36, 640, 320)
# ground truth max and min value: 0.00019683072335400866 1.3863970894985835e-09
# Processing patient file1000351 in batch train
# ground truth shape: (38, 640, 320)
# ground truth max and min value: 0.00017108485338830377 2.8256802128663603e-09
# Processing patient file1000416 in batch train
# ground truth shape: (40, 640, 320)
# ground truth max and min value: 0.0004518998678020072 1.5272069966890274e-09
# Processing patient file1000250 in batch train
# ground truth shape: (30, 640, 320)
# ground truth max and min value: 0.00018891812273811608 2.035798421892224e-09
# Processing patient file1000154 in batch train
# ground truth shape: (34, 640, 320)
# ground truth max and min value: 0.00015479717151910312 3.1709799398519515e-09
# Processing patient file1000058 in batch train
# ground truth shape: (38, 640, 320)
# ground truth max and min value: 0.0006412261211361012 4.158959974041769e-09
# Processing patient file1000467 in batch train
# ground truth shape: (38, 640, 320)
# ground truth max and min value: 0.000445784953738477 2.22053349857385e-09
# Processing patient file1000094 in batch train
# ground truth shape: (33, 640, 320)
# ground truth max and min value: 0.00020367089815336354 2.907557625255391e-09
# Processing patient file1000057 in batch train
# ground truth shape: (42, 640, 320)
# ground truth max and min value: 0.0003502008216957493 2.3740196587182317e-09
# Processing patient file1000060 in batch train
# ground truth shape: (33, 640, 320)
# ground truth max and min value: 0.00024042296864704204 2.054084709349595e-09
# Processing patient file1000495 in batch train
# ground truth shape: (34, 640, 320)
# ground truth max and min value: 0.00022136315877577245 4.629984269274159e-09
# Processing patient file1000554 in batch train
# ground truth shape: (41, 640, 320)
# ground truth max and min value: 0.0005275352835426093 3.461750053202097e-09
# Processing patient file1000566 in batch train
# ground truth shape: (30, 640, 320)
# ground truth max and min value: 0.00032024343856665153 1.902362044212312e-09
# Processing patient file1000204 in batch train
# ground truth shape: (38, 640, 320)
# ground truth max and min value: 0.0001642934346473204 3.202485523389976e-09
# Processing patient file1000097 in batch train
# ground truth shape: (36, 640, 320)
# ground truth max and min value: 0.00028166611266167445 4.415342275408401e-09
# Processing patient file1000210 in batch train
# ground truth shape: (30, 640, 320)
# ground truth max and min value: 0.00027151968021291216 1.1871935500301512e-09
# Processing patient file1000340 in batch train
# ground truth shape: (37, 640, 320)
# ground truth max and min value: 0.0001379047231798106 4.4953984396025584e-09
# Processing patient file1000448 in batch train
# ground truth shape: (35, 640, 320)
# ground truth max and min value: 0.00020891717899526637 7.334500556336828e-09
# Processing patient file1000408 in batch train
# ground truth shape: (35, 640, 320)
# ground truth max and min value: 0.00014053211052661901 8.404163154603148e-10
# Processing patient file1000010 in batch train
# ground truth shape: (36, 640, 320)
# ground truth max and min value: 0.0011910665690596123 2.5075672795807312e-09
# Processing patient file1000535 in batch train
# ground truth shape: (36, 640, 320)
# ground truth max and min value: 0.0003255928394963306 4.798268303969502e-09
# Processing patient file1000378 in batch train
# ground truth shape: (34, 640, 320)
# ground truth max and min value: 0.0004152416865416434 4.9669357287186414e-09
# Processing patient file1000426 in batch train
# ground truth shape: (34, 640, 320)
# ground truth max and min value: 0.0010078116663456147 2.1712972782029865e-09
# Processing patient file1000059 in batch train
# ground truth shape: (38, 640, 320)
# ground truth max and min value: 0.0002221359716097402 1.994930847287987e-09
# Processing patient file1000383 in batch train
# ground truth shape: (39, 640, 320)
# ground truth max and min value: 0.0005626079572047829 5.170426960073136e-09
# Processing patient file1000117 in batch train
# ground truth shape: (35, 640, 320)
# ground truth max and min value: 0.0004988452651067985 2.9648515151407816e-09
# Processing patient file1000452 in batch train
# ground truth shape: (34, 640, 320)
# ground truth max and min value: 0.000184860426217465 4.660051368056416e-10
# Processing patient file1000015 in batch train
# ground truth shape: (36, 640, 320)
# ground truth max and min value: 0.00023520986231414864 1.1358196187889977e-09
# Processing patient file1000300 in batch train
# ground truth shape: (30, 640, 320)
# ground truth max and min value: 0.0003433678502865478 2.062876831270184e-09
# Processing patient file1000021 in batch val
# ground truth shape: (35, 640, 320)
# ground truth max and min value: 0.0007460230323720507 3.6652700573937706e-09
# Processing patient file1000501 in batch val
# ground truth shape: (35, 640, 320)
# ground truth max and min value: 0.00011743859823533286 2.691397594714834e-09
# Processing patient file1000449 in batch val
# ground truth shape: (40, 640, 320)
# ground truth max and min value: 0.00044834801079592416 3.6916926603412475e-09
# Processing patient file1000331 in batch val
# ground truth shape: (34, 640, 320)
# ground truth max and min value: 0.0005735997020045176 2.8049390862764253e-09
# Processing patient file1000493 in batch val
# ground truth shape: (32, 640, 320)
# ground truth max and min value: 0.0004456029712037404 2.7777593386493163e-09
# Processing patient file1000109 in batch test
# ground truth shape: (33, 640, 320)
# ground truth max and min value: 0.00047116551461922777 5.729119193848425e-09
# Processing patient file1000311 in batch test
# ground truth shape: (30, 640, 320)
# ground truth max and min value: 0.00011771037655191643 3.3120453853008087e-09
# Processing patient file1000244 in batch test
# ground truth shape: (37, 640, 320)
# ground truth max and min value: 0.0007424796109307929 4.318235896668766e-09
# Processing patient file1000588 in batch test
# ground truth shape: (35, 640, 320)
# ground truth max and min value: 0.0004863425672558785 3.4531763784140246e-09
# Processing patient file1000275 in batch test
# ground truth shape: (32, 640, 320)
# ground truth max and min value: 0.0002765371106700681 8.304859598348597e-10
# Processing patient file1000089 in batch test
# ground truth shape: (39, 640, 320)
# ground truth max and min value: 0.0008468579287317305 9.60737948279237e-09
# Processing patient file1000499 in batch test
# ground truth shape: (37, 640, 320)
# ground truth max and min value: 0.0007027222379205335 1.2884979976850724e-09
# Processing patient file1000181 in batch test
# ground truth shape: (37, 640, 320)
# ground truth max and min value: 0.00020481840244445748 3.559943869954118e-09
# Processing patient file1000382 in batch test
# ground truth shape: (33, 640, 320)
# ground truth max and min value: 0.0002964700733094701 3.551793850970082e-09
# Processing patient file1000475 in batch test
# ground truth shape: (35, 640, 320)
# ground truth max and min value: 0.00011834999424323376 2.4183121370429366e-09

# %% [markdown]
# ### build list for distillation

# %%
patient_sheet = pd.read_excel(os.path.join('/host/d/Data/low_dose_CT/Patient_lists/mayo_low_dose_CT_batched.xlsx'),dtype={'Patient_ID': str})
noise_types = ['gaussian']
simulation_num = 1

data_path = '/host/d/Data/low_dose_CT/'

for noise_type in noise_types:
    results = []
    for i in range(0, len(patient_sheet)):
        patient_id = patient_sheet['Patient_ID'][i]
        batch = patient_sheet['batch'][i]
        print(f"Processing patient {patient_id} in batch {batch} with noise type {noise_type}")


        ground_truth_file = os.path.join(data_path,'nii_imgs', patient_id, 'img_sliced.nii.gz')
        # img = nb.load(ground_truth_file).get_fdata()
        print('ground truth max and min value:', max_value, min_value)


        for n in range(0,simulation_num):
            n_type = 'gaussian' if noise_type == 'gaussian' else 'poisson'
            simulation_file_all = os.path.join(data_path,'simulation_v2', patient_id, n_type + '_random_' + str(n), 'recon_all_sliced.nii.gz')
            simulation_file_odd = os.path.join(data_path,'simulation_v2', patient_id, n_type + '_random_' + str(n), 'recon_odd_sliced.nii.gz')
            simulation_file_even = os.path.join(data_path,'simulation_v2', patient_id, n_type + '_random_' + str(n), 'recon_even_sliced.nii.gz')

            generated_20_file = os.path.join('/host/d/projects/denoising/models/unsupervised_gaussian_2/pred_images_input_both', patient_id, 'random_' + str(n), 'epoch190avg/pred_img_scans20.nii.gz')
            generated_10_file = os.path.join('/host/d/projects/denoising/models/unsupervised_gaussian_2/pred_images_input_both', patient_id, 'random_' + str(n), 'epoch190avg/pred_img_scans10.nii.gz')
            

            results.append([batch,patient_id, n, simulation_file_all, simulation_file_odd, simulation_file_even, ground_truth_file, 100, generated_20_file, generated_10_file])

        df = pd.DataFrame(results, columns=['batch','Patient_ID', 'random_num', 'simulation_file_all','simulation_file_odd', 'simulation_file_even', 'ground_truth_file', 'slice_num', 'generated_20_file', 'generated_10_file'])
        df.to_excel(os.path.join('/host/d/Data/low_dose_CT/Patient_lists', 'mayo_low_dose_CT_distill_v2.xlsx'), index=False)
# Out:
# Processing patient L333 in batch train with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
# Processing patient L096 in batch train with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
# Processing patient L286 in batch train with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
# Processing patient L067 in batch train with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
# Processing patient L310 in batch train with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
# Processing patient L109 in batch train with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
# Processing patient L506 in batch val with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
# Processing patient L192 in batch test with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
# Processing patient L143 in batch test with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
# Processing patient L291 in batch test with noise type gaussian
# ground truth max and min value: 3071.0 -1024.0
